# %% [markdown]
# 今のところ、データ収集の部分のみが完了しています。

# %%
# libraryをimportする
import os
import re
import zipfile
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

# %%
# 江戸川乱歩の作者ページを設定する
edokawa_url = "https://www.aozora.gr.jp/index_pages/person1779.html"


# 青空文庫のページをUTF-8のencodingで取得する
response = requests.get(edokawa_url)
response.encoding = 'utf-8'

# BeautifulSoupを用いで、HTMLを解析する
soup = BeautifulSoup(response.text, 'html.parser')

# 作品リストを取得する
books_list = soup.select('ol li a')  

# 情報を抽出する
books = []
for book in books_list:
    relative_link = book['href'] 

    # 「person」が含まるlinkを無視する
    if "person" in relative_link:
        continue

    full_link = f"https://www.aozora.gr.jp{relative_link[2:]}"  # full linkに転換する
    book_name = book.text.strip()  # 作品名を収集する
    book_id = relative_link.split('/')[-1].replace('card', '').replace('.html', '')  # 作品IDを収集する

    # 作品の情報を基づいてdictionaryを作る
    books.append({book_id: [book_name, full_link]})

# dictionaryをprintする
for book in books:
    print(book)
# Out:
# {'57105': ['赤いカブトムシ', 'https://www.aozora.gr.jp/cards/001779/card57105.html']}
# {'57181': ['赤い部屋', 'https://www.aozora.gr.jp/cards/001779/card57181.html']}
# {'57240': ['悪魔の紋章', 'https://www.aozora.gr.jp/cards/001779/card57240.html']}
# {'57515': ['悪霊', 'https://www.aozora.gr.jp/cards/001779/card57515.html']}
# {'58699': ['悪霊物語', 'https://www.aozora.gr.jp/cards/001779/card58699.html']}
# {'59399': ['「悪霊物語」自作解説', 'https://www.aozora.gr.jp/cards/001779/card59399.html']}
# {'58333': ['暗黒星', 'https://www.aozora.gr.jp/cards/001779/card58333.html']}
# {'57531': ['偉大なる夢', 'https://www.aozora.gr.jp/cards/001779/card57531.html']}
# {'57182': ['一枚の切符', 'https://www.aozora.gr.jp/cards/001779/card57182.html']}
# {'58053': ['一寸法師', 'https://www.aozora.gr.jp/cards/001779/card58053.html']}
# {'57503': ['陰獣', 'https://www.aozora.gr.jp/cards/001779/card57503.html']}
# {'56674': ['宇宙怪人', 'https://www.aozora.gr.jp/cards/001779/card56674.html']}
# {'58590': ['江川蘭子', 'https://www.aozora.gr.jp/cards/001779/card58590.html']}
# {'57241': ['黄金仮面', 'https://www.aozora.gr.jp/cards/001779/card57241.html']}
# {'56678': ['黄金豹', 'https://www.aozora.gr.jp/cards/001779/card56678.html']}
# {'56645': ['押絵と旅する男', 'https://www.aozora.gr.jp/cards/001779/card56645.html']}
# {'57504': ['お勢登場', 'https://www.aozora.gr.jp/cards/001779/card57504.html']}
# {'57183': ['恐ろしき錯誤', 'https://www.aozora.gr.jp/cards/001779/card57183.html']}
# {'57505': ['踊る一寸法師', 'https://www.aozora.gr.jp/cards/001779/card57505.html']}
# {'57516': ['鬼', 'https://www.aozora.gr.jp/cards/001779/card57516.html']}
# {'56690': ['おれは二十面相だ', 'https://www.aozora.gr.jp/cards/001779/card56690.html']}
# {'56673': ['怪奇四十面相', 'https://www.aozora.gr.jp/cards/001779/card56673.html']}
# {'57225': ['怪人と少年探偵', 'https://www.aozora.gr.jp/cards/001779/card57225.html']}
# {'57227': ['かいじん二十めんそう', 'https://www.aozora.gr.jp/cards/001779/card57227.html']}
# {'57228': ['怪人二十面相', 'https://www.aozora.gr.jp/cards/001779/card57228.html']}
# {'57226': ['かいじん二十めんそう', 'https://www.aozora.gr.jp/cards/001779/card57226.html']}
# {'56677': ['海底の魔術師', 'https://www.aozora.gr.jp/cards/001779/card56677.html']}
# {'57343': ['鏡地獄', 'https://www.aozora.gr.jp/cards/001779/card57343.html']}
# {'58486': ['影男', 'https://www.aozora.gr.jp/cards/001779/card58486.html']}
# {'57506': ['火星の運河', 'https://www.aozora.gr.jp/cards/001779/card57506.html']}
# {'56688': ['仮面の恐怖王', 'https://www.aozora.gr.jp/cards/001779/card56688.html']}
# {'56683': ['奇面城の秘密', 'https://www.aozora.gr.jp/cards/001779/card56683.html']}
# {'56658': ['吸血鬼', 'https://www.aozora.gr.jp/cards/001779/card56658.html']}
# {'57517': ['恐怖王', 'https://www.aozora.gr.jp/cards/001779/card57517.html']}
# {'57184': ['疑惑', 'https://www.aozora.gr.jp/cards/001779/card57184.html']}
# {'57185': ['黒手組', 'https://www.aozora.gr.jp/cards/001779/card57185.html']}
# {'57405': ['黒蜥蜴', 'https://www.aozora.gr.jp/cards/001779/card57405.html']}
# {'57508': ['五階の窓', 'https://www.aozora.gr.jp/cards/001779/card57508.html']}
# {'57849': ['孤島の鬼', 'https://www.aozora.gr.jp/cards/001779/card57849.html']}
# {'58039': ['湖畔亭事件', 'https://www.aozora.gr.jp/cards/001779/card58039.html']}
# {'56680': ['サーカスの怪人', 'https://www.aozora.gr.jp/cards/001779/card56680.html']}
# {'57518': ['殺人迷路', 'https://www.aozora.gr.jp/cards/001779/card57518.html']}
# {'57519': ['地獄風景', 'https://www.aozora.gr.jp/cards/001779/card57519.html']}
# {'57316': ['自作解説', 'https://www.aozora.gr.jp/cards/001779/card57316.html']}
# {'56669': ['少年探偵団', 'https://www.aozora.gr.jp/cards/001779/card56669.html']}
# {'59305': ['女妖', 'https://www.aozora.gr.jp/cards/001779/card59305.html']}
# {'57532': ['新宝島', 'https://www.aozora.gr.jp/cards/001779/card57532.html']}
# {'56646': ['心理試験', 'https://www.aozora.gr.jp/cards/001779/card56646.html']}
# {'54836': ['随筆銭形平次', 'https://www.aozora.gr.jp/cards/001670/card54836.html']}
# {'56671': ['青銅の魔人', 'https://www.aozora.gr.jp/cards/001779/card56671.html']}
# {'57186': ['接吻', 'https://www.aozora.gr.jp/cards/001779/card57186.html']}
# {'57187': ['双生児', 'https://www.aozora.gr.jp/cards/001779/card57187.html']}
# {'57188': ['算盤が恋を語る話', 'https://www.aozora.gr.jp/cards/001779/card57188.html']}
# {'57106': ['大金塊', 'https://www.aozora.gr.jp/cards/001779/card57106.html']}
# {'58462': ['断崖', 'https://www.aozora.gr.jp/cards/001779/card58462.html']}
# {'57502': ['探偵小説の「謎」', 'https://www.aozora.gr.jp/cards/001779/card57502.html']}
# {'56686': ['探偵少年', 'https://www.aozora.gr.jp/cards/001779/card56686.html']}
# {'57533': ['智恵の一太郎', 'https://www.aozora.gr.jp/cards/001779/card57533.html']}
# {'57107': ['超人ニコラ', 'https://www.aozora.gr.jp/cards/001779/card57107.html']}
# {'58463': ['月と手袋', 'https://www.aozora.gr.jp/cards/001779/card58463.html']}
# {'58464': ['妻に失恋した男', 'https://www.aozora.gr.jp/cards/001779/card58464.html']}
# {'59526': ['妻のこと', 'https://www.aozora.gr.jp/cards/001779/card59526.html']}
# {'56650': ['Ｄ坂の殺人事件', 'https://www.aozora.gr.jp/cards/001779/card56650.html']}
# {'57108': ['鉄人Ｑ', 'https://www.aozora.gr.jp/cards/001779/card57108.html']}
# {'56675': ['鉄塔の怪人', 'https://www.aozora.gr.jp/cards/001779/card56675.html']}
# {'56687': ['天空の魔人', 'https://www.aozora.gr.jp/cards/001779/card56687.html']}
# {'56689': ['電人Ｍ', 'https://www.aozora.gr.jp/cards/001779/card56689.html']}
# {'57109': ['塔上の奇術師', 'https://www.aozora.gr.jp/cards/001779/card57109.html']}
# {'57189': ['盗難', 'https://www.aozora.gr.jp/cards/001779/card57189.html']}
# {'57229': ['透明怪人', 'https://www.aozora.gr.jp/cards/001779/card57229.html']}
# {'57509': ['毒草', 'https://www.aozora.gr.jp/cards/001779/card57509.html']}
# {'56672': ['虎の牙', 'https://www.aozora.gr.jp/cards/001779/card56672.html']}
# {'57243': ['何者', 'https://www.aozora.gr.jp/cards/001779/card57243.html']}
# {'56647': ['二銭銅貨', 'https://www.aozora.gr.jp/cards/001779/card56647.html']}
# {'57190': ['日記帳', 'https://www.aozora.gr.jp/cards/001779/card57190.html']}
# {'57191': ['二癈人', 'https://www.aozora.gr.jp/cards/001779/card57191.html']}
# {'56648': ['人間椅子', 'https://www.aozora.gr.jp/cards/001779/card56648.html']}
# {'58170': ['人間豹', 'https://www.aozora.gr.jp/cards/001779/card58170.html']}
# {'56676': ['灰色の巨人', 'https://www.aozora.gr.jp/cards/001779/card56676.html']}
# {'57510': ['灰神楽', 'https://www.aozora.gr.jp/cards/001779/card57510.html']}
# {'57192': ['白昼夢', 'https://www.aozora.gr.jp/cards/001779/card57192.html']}
# {'57244': ['白髪鬼', 'https://www.aozora.gr.jp/cards/001779/card57244.html']}
# {'56651': ['パノラマ島綺譚', 'https://www.aozora.gr.jp/cards/001779/card56651.html']}
# {'60174': ['薔薇夫人', 'https://www.aozora.gr.jp/cards/001779/card60174.html']}
# {'57511': ['人でなしの恋', 'https://www.aozora.gr.jp/cards/001779/card57511.html']}
# {'57414': ['一人の芭蕉の問題', 'https://www.aozora.gr.jp/cards/001779/card57414.html']}
# {'57193': ['一人二役', 'https://www.aozora.gr.jp/cards/001779/card57193.html']}
# {'57520': ['火縄銃', 'https://www.aozora.gr.jp/cards/001779/card57520.html']}
# {'57194': ['百面相役者', 'https://www.aozora.gr.jp/cards/001779/card57194.html']}
# {'57512': ['覆面の舞踏者', 'https://www.aozora.gr.jp/cards/001779/card57512.html']}
# {'57230': ['ふしぎな人', 'https://www.aozora.gr.jp/cards/001779/card57230.html']}
# {'56659': ['魔術師', 'https://www.aozora.gr.jp/cards/001779/card56659.html']}
# {'56682': ['魔法人形', 'https://www.aozora.gr.jp/cards/001779/card56682.html']}
# {'56679': ['魔法博士', 'https://www.aozora.gr.jp/cards/001779/card56679.html']}
# {'57165': ['まほうやしき', 'https://www.aozora.gr.jp/cards/001779/card57165.html']}
# {'57245': ['虫', 'https://www.aozora.gr.jp/cards/001779/card57245.html']}
# {'57195': ['夢遊病者の死', 'https://www.aozora.gr.jp/cards/001779/card57195.html']}
# {'57521': ['目羅博士の不思議な犯罪', 'https://www.aozora.gr.jp/cards/001779/card57521.html']}
# {'57513': ['木馬は廻る', 'https://www.aozora.gr.jp/cards/001779/card57513.html']}
# {'57514': ['モノグラム', 'https://www.aozora.gr.jp/cards/001779/card57514.html']}
# {'56684': ['夜光人間', 'https://www.aozora.gr.jp/cards/001779/card56684.html']}
# {'56649': ['屋根裏の散歩者', 'https://www.aozora.gr.jp/cards/001779/card56649.html']}
# {'57196': ['幽霊', 'https://www.aozora.gr.jp/cards/001779/card57196.html']}
# {'58465': ['指', 'https://www.aozora.gr.jp/cards/001779/card58465.html']}
# {'57197': ['指環', 'https://www.aozora.gr.jp/cards/001779/card57197.html']}
# {'56670': ['妖怪博士', 'https://www.aozora.gr.jp/cards/001779/card56670.html']}
# {'56681': ['妖人ゴング', 'https://www.aozora.gr.jp/cards/001779/card56681.html']}
# {'56691': ['妖星人Ｒ', 'https://www.aozora.gr.jp/cards/001779/card56691.html']}
# {'57522': ['妖虫', 'https://www.aozora.gr.jp/cards/001779/card57522.html']}
# {'58467': ['猟奇の果', 'https://www.aozora.gr.jp/cards/001779/card58467.html']}

# %%
def clean_and_extract_publication_year(text):
    # 出版した時間を抽出する
    cleaned_text = re.sub(r"（[^）]*）", "", text)
    pattern = r"(\d{4})"
    match = re.search(pattern, cleaned_text)
    if match:
        return match.group(1)
    return None

def extract_download_links(soup, base_url):
    # Webからすべての .zip download linkを抽出する
    download_links = []
    download_table = soup.find('table', class_='download')
    if download_table:
        download_rows = download_table.find_all('tr', bgcolor='white')
        for row in download_rows:
            link_tag = row.find('a', href=True)
            if link_tag and link_tag['href'].endswith('.zip'):
                full_url = urljoin(base_url, link_tag['href'])
                download_links.append(full_url)
    return download_links

def download_file(url, save_folder):
    # URLに従ってfileをdownloadし、指定されたfolderに保存する
    response = requests.get(url)
    response.raise_for_status()
    filename = url.split('/')[-1]
    save_path = os.path.join(save_folder, filename)
    os.makedirs(save_folder, exist_ok=True)
    with open(save_path, 'wb') as file:
        file.write(response.content)
    return save_path

def extract_zip(zip_path, extract_folder):
    # .zip fileを目的のfolderに解凍する
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
        return zip_ref.namelist() 

def rename_and_move_files(extracted_files, year, save_folder):
    # 解凍したfileの名前を変更して移動する
    renamed_files = []
    for file in extracted_files:
        old_path = os.path.join(save_folder, file)
        new_filename = f"{year}_{file}"
        new_path = os.path.join(save_folder, new_filename)
        os.rename(old_path, new_path)
        renamed_files.append(new_path)
    return renamed_files

def process_download_and_extract(url, save_folder, year):
    # .zipのfileをdownloadし、解凍して名前を変更する
    zip_path = download_file(url, save_folder)
    extracted_files = extract_zip(zip_path, save_folder)
    renamed_files = rename_and_move_files(extracted_files, year, save_folder)
    os.remove(zip_path)
    return renamed_files

# def process_books(book_dict_list, save_folder):
#     # すべてのprocessを統合する
#     for book_dict in book_dict_list:
#         for book_id, book_info in book_dict.items():
#             book_name, book_url = book_info  # 小説の情報を解析する
            
#             # ウェブページのHTMLを取得して解析する
#             response = requests.get(book_url)
#             response.encoding = 'utf-8'
#             soup = BeautifulSoup(response.text, 'html.parser')
            
#             # 初出年份を抽出する
#             try:
#                 initial_publication = soup.find('td', class_='header', string='初出：').find_next('td').get_text(strip=True)
#                 publication_year = clean_and_extract_publication_year(initial_publication)
#             except AttributeError:
#                 publication_year = "未知"
            
#             # download linkを抽出する
#             download_links = extract_download_links(soup, os.path.dirname(book_url) + '/')
            
#             # fileをdownloadし、解凍して名前を変更する
#             for link in download_links:
#                 renamed_files = process_download_and_extract(link, save_folder, publication_year)
#                 book_info.extend([publication_year] + renamed_files)

def process_books(book_dict_list, save_folder):
    # すべてのprocessを統合する
    for book_dict in book_dict_list:
        for book_id, book_info in book_dict.items():
            book_name, book_url = book_info  # 小説の情報を解析する
            
            # ウェブページのHTMLを取得して解析する
            response = requests.get(book_url)
            response.encoding = 'utf-8'
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # 初出年份を抽出する
            try:
                initial_publication = soup.find('td', class_='header', string='初出：').find_next('td').get_text(strip=True)
                publication_year = clean_and_extract_publication_year(initial_publication)
            except AttributeError:
                publication_year = "未知"
            
            # download linkを抽出する
            download_links = extract_download_links(soup, os.path.dirname(book_url) + '/')
            
            # fileをdownloadし、解凍して名前を変更する
            for link in download_links:
                renamed_files = process_download_and_extract(link, save_folder, publication_year)
                book_info.extend([publication_year] + renamed_files)
    
    # 过滤掉 .png 文件路径
    for book in book_dict_list:
        for book_id, book_info in book.items():
            # 删除所有 .png 文件路径
            book_info = [info for info in book_info if not info.endswith('.png')]

save_folder = '/Users/yandongxin/Downloads/edokawa_text_data'

process_books(books, save_folder)

# 结果を表示する
for book in books:
    print(book)
# Out:
# 57105 ['赤いカブトムシ', 'https://www.aozora.gr.jp/cards/001779/card57105.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_akai_kabutomushi.txt']
# 57181 ['赤い部屋', 'https://www.aozora.gr.jp/cards/001779/card57181.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_akai_heya.txt']
# 57240 ['悪魔の紋章', 'https://www.aozora.gr.jp/cards/001779/card57240.html', '1937', '/Users/yandongxin/Downloads/edokawa_text_data/1937_akumano_monsho.txt']
# 57515 ['悪霊', 'https://www.aozora.gr.jp/cards/001779/card57515.html', '1933', '/Users/yandongxin/Downloads/edokawa_text_data/1933_akuryo.txt']
# 58699 ['悪霊物語', 'https://www.aozora.gr.jp/cards/001779/card58699.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_akuryo_monogatari.txt']
# 59399 ['「悪霊物語」自作解説', 'https://www.aozora.gr.jp/cards/001779/card59399.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_akuryo_monogatari_jisaku_kaisetsu.txt']
# 58333 ['暗黒星', 'https://www.aozora.gr.jp/cards/001779/card58333.html', '1939', '/Users/yandongxin/Downloads/edokawa_text_data/1939_ankokusei.txt']
# 57531 ['偉大なる夢', 'https://www.aozora.gr.jp/cards/001779/card57531.html', '1943', '/Users/yandongxin/Downloads/edokawa_text_data/1943_idai_naru_yume.txt']
# 57182 ['一枚の切符', 'https://www.aozora.gr.jp/cards/001779/card57182.html', '1923', '/Users/yandongxin/Downloads/edokawa_text_data/1923_ichimaino_kippu.txt']
# 58053 ['一寸法師', 'https://www.aozora.gr.jp/cards/001779/card58053.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_issunboshi.txt']
# 57503 ['陰獣', 'https://www.aozora.gr.jp/cards/001779/card57503.html', '1928', '/Users/yandongxin/Downloads/edokawa_text_data/1928_inju.txt']
# 56674 ['宇宙怪人', 'https://www.aozora.gr.jp/cards/001779/card56674.html', '1953', '/Users/yandongxin/Downloads/edokawa_text_data/1953_uchu_kaijin.txt']
# 58590 ['江川蘭子', 'https://www.aozora.gr.jp/cards/001779/card58590.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_egawa_ranko.txt']
# 57241 ['黄金仮面', 'https://www.aozora.gr.jp/cards/001779/card57241.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_ogon_kamen.txt']
# 56678 ['黄金豹', 'https://www.aozora.gr.jp/cards/001779/card56678.html', '1956', '/Users/yandongxin/Downloads/edokawa_text_data/1956_ogon_hyo.txt']
# 56645 ['押絵と旅する男', 'https://www.aozora.gr.jp/cards/001779/card56645.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_oshieto_tabisuru_otoko.txt']
# 57504 ['お勢登場', 'https://www.aozora.gr.jp/cards/001779/card57504.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_osei_tojo.txt']
# 57183 ['恐ろしき錯誤', 'https://www.aozora.gr.jp/cards/001779/card57183.html', '1923', '/Users/yandongxin/Downloads/edokawa_text_data/1923_osoroshiki_sakugo.txt']
# 57505 ['踊る一寸法師', 'https://www.aozora.gr.jp/cards/001779/card57505.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_odoru_issun_boshi.txt']
# 57516 ['鬼', 'https://www.aozora.gr.jp/cards/001779/card57516.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_oni.txt']
# 56690 ['おれは二十面相だ', 'https://www.aozora.gr.jp/cards/001779/card56690.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_orewa_nijumensoda.txt']
# 56673 ['怪奇四十面相', 'https://www.aozora.gr.jp/cards/001779/card56673.html', '1952', '/Users/yandongxin/Downloads/edokawa_text_data/1952_kaiki_yonju_menso.txt']
# 57225 ['怪人と少年探偵', 'https://www.aozora.gr.jp/cards/001779/card57225.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_kaijinto_shonen_tantei.txt']
# 57227 ['かいじん二十めんそう', 'https://www.aozora.gr.jp/cards/001779/card57227.html', '1959', '/Users/yandongxin/Downloads/edokawa_text_data/1959_kaijin_nijumenso_57227.txt']
# 57228 ['怪人二十面相', 'https://www.aozora.gr.jp/cards/001779/card57228.html', '1936', '/Users/yandongxin/Downloads/edokawa_text_data/1936_kaijin_nijumenso.txt']
# 57226 ['かいじん二十めんそう', 'https://www.aozora.gr.jp/cards/001779/card57226.html', '1959', '/Users/yandongxin/Downloads/edokawa_text_data/1959_kaijin_nijumenso_57226.txt']
# 56677 ['海底の魔術師', 'https://www.aozora.gr.jp/cards/001779/card56677.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_kaiteino_majutsushi.txt']
# 57343 ['鏡地獄', 'https://www.aozora.gr.jp/cards/001779/card57343.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_kagami_jigoku.txt']
# 58486 ['影男', 'https://www.aozora.gr.jp/cards/001779/card58486.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_kageotoko.txt']
# 57506 ['火星の運河', 'https://www.aozora.gr.jp/cards/001779/card57506.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_kaseino_unga.txt']
# 56688 ['仮面の恐怖王', 'https://www.aozora.gr.jp/cards/001779/card56688.html', '1959', '/Users/yandongxin/Downloads/edokawa_text_data/1959_kamenno_kyofuo.txt']
# 56683 ['奇面城の秘密', 'https://www.aozora.gr.jp/cards/001779/card56683.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_kimenjono_himitsu.txt']
# 56658 ['吸血鬼', 'https://www.aozora.gr.jp/cards/001779/card56658.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_kyuketsuki.txt']
# 57517 ['恐怖王', 'https://www.aozora.gr.jp/cards/001779/card57517.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_kyofu_o.txt']
# 57184 ['疑惑', 'https://www.aozora.gr.jp/cards/001779/card57184.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_giwaku.txt']
# 57185 ['黒手組', 'https://www.aozora.gr.jp/cards/001779/card57185.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_kurote_gumi.txt']
# 57405 ['黒蜥蜴', 'https://www.aozora.gr.jp/cards/001779/card57405.html', '1934', '/Users/yandongxin/Downloads/edokawa_text_data/1934_kurotokage.txt']
# 57508 ['五階の窓', 'https://www.aozora.gr.jp/cards/001779/card57508.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_gokaino_mado_01.txt']
# 57849 ['孤島の鬼', 'https://www.aozora.gr.jp/cards/001779/card57849.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_kotono_oni.txt']
# 58039 ['湖畔亭事件', 'https://www.aozora.gr.jp/cards/001779/card58039.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_kohantei_jiken.txt']
# 56680 ['サーカスの怪人', 'https://www.aozora.gr.jp/cards/001779/card56680.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_sakasuno_kaijin.txt']
# 57518 ['殺人迷路', 'https://www.aozora.gr.jp/cards/001779/card57518.html', '1932', '/Users/yandongxin/Downloads/edokawa_text_data/1932_satsujin_meiro_05.txt']
# 57519 ['地獄風景', 'https://www.aozora.gr.jp/cards/001779/card57519.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_jigoku_fukei.txt']
# 57316 ['自作解説', 'https://www.aozora.gr.jp/cards/001779/card57316.html', '1965', '/Users/yandongxin/Downloads/edokawa_text_data/1965_jisaku_kaisetsu_kaijin_nijumenso.txt']
# 56669 ['少年探偵団', 'https://www.aozora.gr.jp/cards/001779/card56669.html', '1937', '/Users/yandongxin/Downloads/edokawa_text_data/1937_shonen_tanteidan.txt']
# 59305 ['女妖', 'https://www.aozora.gr.jp/cards/001779/card59305.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_joyo01.txt']
# 57532 ['新宝島', 'https://www.aozora.gr.jp/cards/001779/card57532.html', '1940', '/Users/yandongxin/Downloads/edokawa_text_data/1940_shin_takarajima.txt']
# 56646 ['心理試験', 'https://www.aozora.gr.jp/cards/001779/card56646.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_shinri_shiken.txt']
# 54836 ['随筆銭形平次', 'https://www.aozora.gr.jp/cards/001670/card54836.html', '1950', '/Users/yandongxin/Downloads/edokawa_text_data/1950_19tanteishosetsu_konogoro.txt']
# 56671 ['青銅の魔人', 'https://www.aozora.gr.jp/cards/001779/card56671.html', '1949', '/Users/yandongxin/Downloads/edokawa_text_data/1949_seidono_majin.txt']
# 57186 ['接吻', 'https://www.aozora.gr.jp/cards/001779/card57186.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_seppun.txt']
# 57187 ['双生児', 'https://www.aozora.gr.jp/cards/001779/card57187.html', '1924', '/Users/yandongxin/Downloads/edokawa_text_data/1924_soseiji.txt']
# 57188 ['算盤が恋を語る話', 'https://www.aozora.gr.jp/cards/001779/card57188.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_sorobanga_koio_kataru_hanashi.txt']
# 57106 ['大金塊', 'https://www.aozora.gr.jp/cards/001779/card57106.html', '1939', '/Users/yandongxin/Downloads/edokawa_text_data/1939_dai_kinkai.txt']
# 58462 ['断崖', 'https://www.aozora.gr.jp/cards/001779/card58462.html', '1950', '/Users/yandongxin/Downloads/edokawa_text_data/1950_dangai.txt']
# 57502 ['探偵小説の「謎」', 'https://www.aozora.gr.jp/cards/001779/card57502.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_tantei_shosetsuno_nazo.txt']
# 56686 ['探偵少年', 'https://www.aozora.gr.jp/cards/001779/card56686.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_tantei_shonen.txt']
# 57533 ['智恵の一太郎', 'https://www.aozora.gr.jp/cards/001779/card57533.html', '1942', '/Users/yandongxin/Downloads/edokawa_text_data/1942_chieno_ichitaro.txt']
# 57107 ['超人ニコラ', 'https://www.aozora.gr.jp/cards/001779/card57107.html', '1962', '/Users/yandongxin/Downloads/edokawa_text_data/1962_chojin_nikora.txt']
# 58463 ['月と手袋', 'https://www.aozora.gr.jp/cards/001779/card58463.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_tsukito_tebukuro.txt']
# 58464 ['妻に失恋した男', 'https://www.aozora.gr.jp/cards/001779/card58464.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_tsumani_shitsuren_shita_otoko.txt']
# 59526 ['妻のこと', 'https://www.aozora.gr.jp/cards/001779/card59526.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_tsumano_koto.txt']
# 56650 ['Ｄ坂の殺人事件', 'https://www.aozora.gr.jp/cards/001779/card56650.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_d_zakano_satsujin_jiken.txt']
# 57108 ['鉄人Ｑ', 'https://www.aozora.gr.jp/cards/001779/card57108.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_tetsujin_kyu.txt']
# 56675 ['鉄塔の怪人', 'https://www.aozora.gr.jp/cards/001779/card56675.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_tettono_kaijin.txt']
# 56687 ['天空の魔人', 'https://www.aozora.gr.jp/cards/001779/card56687.html', '1956', '/Users/yandongxin/Downloads/edokawa_text_data/1956_tenkuno_majin.txt']
# 56689 ['電人Ｍ', 'https://www.aozora.gr.jp/cards/001779/card56689.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_denjin_emu.txt']
# 57109 ['塔上の奇術師', 'https://www.aozora.gr.jp/cards/001779/card57109.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_tojono_kijutsushi.txt']
# 57189 ['盗難', 'https://www.aozora.gr.jp/cards/001779/card57189.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_tonan.txt']
# 57229 ['透明怪人', 'https://www.aozora.gr.jp/cards/001779/card57229.html', '1951', '/Users/yandongxin/Downloads/edokawa_text_data/1951_tomei_kaijin.txt']
# 57509 ['毒草', 'https://www.aozora.gr.jp/cards/001779/card57509.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_dokuso.txt']
# 56672 ['虎の牙', 'https://www.aozora.gr.jp/cards/001779/card56672.html', '1950', '/Users/yandongxin/Downloads/edokawa_text_data/1950_torano_kiba.txt']
# 57243 ['何者', 'https://www.aozora.gr.jp/cards/001779/card57243.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_nanimono.txt']
# 56647 ['二銭銅貨', 'https://www.aozora.gr.jp/cards/001779/card56647.html', '1923', '/Users/yandongxin/Downloads/edokawa_text_data/1923_nisen_doka.txt']
# 57190 ['日記帳', 'https://www.aozora.gr.jp/cards/001779/card57190.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_nikkicho.txt']
# 57191 ['二癈人', 'https://www.aozora.gr.jp/cards/001779/card57191.html', '1924', '/Users/yandongxin/Downloads/edokawa_text_data/1924_nihaijin.txt']
# 56648 ['人間椅子', 'https://www.aozora.gr.jp/cards/001779/card56648.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_ningen_isu.txt']
# 58170 ['人間豹', 'https://www.aozora.gr.jp/cards/001779/card58170.html', '1934', '/Users/yandongxin/Downloads/edokawa_text_data/1934_ningen_hyo.txt']
# 56676 ['灰色の巨人', 'https://www.aozora.gr.jp/cards/001779/card56676.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_haiirono_kyojin.txt']
# 57510 ['灰神楽', 'https://www.aozora.gr.jp/cards/001779/card57510.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_haikagura.txt']
# 57192 ['白昼夢', 'https://www.aozora.gr.jp/cards/001779/card57192.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_hakuchumu.txt']
# 57244 ['白髪鬼', 'https://www.aozora.gr.jp/cards/001779/card57244.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_hakuhatsu_ki.txt']
# 56651 ['パノラマ島綺譚', 'https://www.aozora.gr.jp/cards/001779/card56651.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_panoramato_kidan.txt']
# 60174 ['薔薇夫人', 'https://www.aozora.gr.jp/cards/001779/card60174.html', '未知', '/Users/yandongxin/Downloads/edokawa_text_data/未知_bara_fujin.txt']
# 57511 ['人でなしの恋', 'https://www.aozora.gr.jp/cards/001779/card57511.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_hitodenashino_koi.txt']
# 57414 ['一人の芭蕉の問題', 'https://www.aozora.gr.jp/cards/001779/card57414.html', '1947', '/Users/yandongxin/Downloads/edokawa_text_data/1947_hitorino_bashono_mondai.txt']
# 57193 ['一人二役', 'https://www.aozora.gr.jp/cards/001779/card57193.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_hitori_futayaku.txt']
# 57520 ['火縄銃', 'https://www.aozora.gr.jp/cards/001779/card57520.html', '1932', '/Users/yandongxin/Downloads/edokawa_text_data/1932_hinawaju.txt']
# 57194 ['百面相役者', 'https://www.aozora.gr.jp/cards/001779/card57194.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_hyakumenso_yakusha.txt']
# 57512 ['覆面の舞踏者', 'https://www.aozora.gr.jp/cards/001779/card57512.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_fukumenno_butosha.txt']
# 57230 ['ふしぎな人', 'https://www.aozora.gr.jp/cards/001779/card57230.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_fushigina_hito.txt']
# 56659 ['魔術師', 'https://www.aozora.gr.jp/cards/001779/card56659.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_majutsushi.txt']
# 56682 ['魔法人形', 'https://www.aozora.gr.jp/cards/001779/card56682.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_maho_ningyo.txt']
# 56679 ['魔法博士', 'https://www.aozora.gr.jp/cards/001779/card56679.html', '1956', '/Users/yandongxin/Downloads/edokawa_text_data/1956_maho_hakase.txt']
# 57165 ['まほうやしき', 'https://www.aozora.gr.jp/cards/001779/card57165.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_maho_yashiki.txt']
# 57245 ['虫', 'https://www.aozora.gr.jp/cards/001779/card57245.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_mushi.txt']
# 57195 ['夢遊病者の死', 'https://www.aozora.gr.jp/cards/001779/card57195.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_muyubyoshano_shi.txt']
# 57521 ['目羅博士の不思議な犯罪', 'https://www.aozora.gr.jp/cards/001779/card57521.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_mera_hakaseno_fushigina_hanzai.txt']
# 57513 ['木馬は廻る', 'https://www.aozora.gr.jp/cards/001779/card57513.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_mokubawa_mawaru.txt']
# 57514 ['モノグラム', 'https://www.aozora.gr.jp/cards/001779/card57514.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_monoguramu.txt']
# 56684 ['夜光人間', 'https://www.aozora.gr.jp/cards/001779/card56684.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_yako_ningen.txt']
# 56649 ['屋根裏の散歩者', 'https://www.aozora.gr.jp/cards/001779/card56649.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_yaneurano_sanposha.txt']
# 57196 ['幽霊', 'https://www.aozora.gr.jp/cards/001779/card57196.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_yurei.txt']
# 58465 ['指', 'https://www.aozora.gr.jp/cards/001779/card58465.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_yubi.txt']
# 57197 ['指環', 'https://www.aozora.gr.jp/cards/001779/card57197.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_yubiwa.txt']
# 56670 ['妖怪博士', 'https://www.aozora.gr.jp/cards/001779/card56670.html', '1938', '/Users/yandongxin/Downloads/edokawa_text_data/1938_yokai_hakase.txt']
# 56681 ['妖人ゴング', 'https://www.aozora.gr.jp/cards/001779/card56681.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_yojin_gongu.txt']
# 56691 ['妖星人Ｒ', 'https://www.aozora.gr.jp/cards/001779/card56691.html', '1961', '/Users/yandongxin/Downloads/edokawa_text_data/1961_yoseijin_r.txt']
# 57522 ['妖虫', 'https://www.aozora.gr.jp/cards/001779/card57522.html', '1933', '/Users/yandongxin/Downloads/edokawa_text_data/1933_yochu.txt']
# 58467 ['猟奇の果', 'https://www.aozora.gr.jp/cards/001779/card58467.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_ryokino_hate.txt']
# {'57105': ['赤いカブトムシ', 'https://www.aozora.gr.jp/cards/001779/card57105.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_akai_kabutomushi.txt']}
# {'57181': ['赤い部屋', 'https://www.aozora.gr.jp/cards/001779/card57181.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_akai_heya.txt']}
# {'57240': ['悪魔の紋章', 'https://www.aozora.gr.jp/cards/001779/card57240.html', '1937', '/Users/yandongxin/Downloads/edokawa_text_data/1937_akumano_monsho.txt']}
# {'57515': ['悪霊', 'https://www.aozora.gr.jp/cards/001779/card57515.html', '1933', '/Users/yandongxin/Downloads/edokawa_text_data/1933_akuryo.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1933_fig57515_01.png']}
# {'58699': ['悪霊物語', 'https://www.aozora.gr.jp/cards/001779/card58699.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_akuryo_monogatari.txt']}
# {'59399': ['「悪霊物語」自作解説', 'https://www.aozora.gr.jp/cards/001779/card59399.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_akuryo_monogatari_jisaku_kaisetsu.txt']}
# {'58333': ['暗黒星', 'https://www.aozora.gr.jp/cards/001779/card58333.html', '1939', '/Users/yandongxin/Downloads/edokawa_text_data/1939_ankokusei.txt']}
# {'57531': ['偉大なる夢', 'https://www.aozora.gr.jp/cards/001779/card57531.html', '1943', '/Users/yandongxin/Downloads/edokawa_text_data/1943_idai_naru_yume.txt']}
# {'57182': ['一枚の切符', 'https://www.aozora.gr.jp/cards/001779/card57182.html', '1923', '/Users/yandongxin/Downloads/edokawa_text_data/1923_ichimaino_kippu.txt']}
# {'58053': ['一寸法師', 'https://www.aozora.gr.jp/cards/001779/card58053.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_issunboshi.txt']}
# {'57503': ['陰獣', 'https://www.aozora.gr.jp/cards/001779/card57503.html', '1928', '/Users/yandongxin/Downloads/edokawa_text_data/1928_inju.txt']}
# {'56674': ['宇宙怪人', 'https://www.aozora.gr.jp/cards/001779/card56674.html', '1953', '/Users/yandongxin/Downloads/edokawa_text_data/1953_uchu_kaijin.txt']}
# {'58590': ['江川蘭子', 'https://www.aozora.gr.jp/cards/001779/card58590.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_egawa_ranko.txt']}
# {'57241': ['黄金仮面', 'https://www.aozora.gr.jp/cards/001779/card57241.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_fig57241_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1930_ogon_kamen.txt']}
# {'56678': ['黄金豹', 'https://www.aozora.gr.jp/cards/001779/card56678.html', '1956', '/Users/yandongxin/Downloads/edokawa_text_data/1956_ogon_hyo.txt']}
# {'56645': ['押絵と旅する男', 'https://www.aozora.gr.jp/cards/001779/card56645.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_oshieto_tabisuru_otoko.txt']}
# {'57504': ['お勢登場', 'https://www.aozora.gr.jp/cards/001779/card57504.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_osei_tojo.txt']}
# {'57183': ['恐ろしき錯誤', 'https://www.aozora.gr.jp/cards/001779/card57183.html', '1923', '/Users/yandongxin/Downloads/edokawa_text_data/1923_osoroshiki_sakugo.txt']}
# {'57505': ['踊る一寸法師', 'https://www.aozora.gr.jp/cards/001779/card57505.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_odoru_issun_boshi.txt']}
# {'57516': ['鬼', 'https://www.aozora.gr.jp/cards/001779/card57516.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_oni.txt']}
# {'56690': ['おれは二十面相だ', 'https://www.aozora.gr.jp/cards/001779/card56690.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_orewa_nijumensoda.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1960_fig56690_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1960_fig56690_02.png', '/Users/yandongxin/Downloads/edokawa_text_data/1960_fig56690_03.png']}
# {'56673': ['怪奇四十面相', 'https://www.aozora.gr.jp/cards/001779/card56673.html', '1952', '/Users/yandongxin/Downloads/edokawa_text_data/1952_kaiki_yonju_menso.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1952_fig56673_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1952_fig56673_02.png', '/Users/yandongxin/Downloads/edokawa_text_data/1952_fig56673_03.png', '/Users/yandongxin/Downloads/edokawa_text_data/1952_fig56673_04.png', '/Users/yandongxin/Downloads/edokawa_text_data/1952_fig56673_05.png']}
# {'57225': ['怪人と少年探偵', 'https://www.aozora.gr.jp/cards/001779/card57225.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_kaijinto_shonen_tantei.txt']}
# {'57227': ['かいじん二十めんそう', 'https://www.aozora.gr.jp/cards/001779/card57227.html', '1959', '/Users/yandongxin/Downloads/edokawa_text_data/1959_kaijin_nijumenso_57227.txt']}
# {'57228': ['怪人二十面相', 'https://www.aozora.gr.jp/cards/001779/card57228.html', '1936', '/Users/yandongxin/Downloads/edokawa_text_data/1936_kaijin_nijumenso.txt']}
# {'57226': ['かいじん二十めんそう', 'https://www.aozora.gr.jp/cards/001779/card57226.html', '1959', '/Users/yandongxin/Downloads/edokawa_text_data/1959_kaijin_nijumenso_57226.txt']}
# {'56677': ['海底の魔術師', 'https://www.aozora.gr.jp/cards/001779/card56677.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_kaiteino_majutsushi.txt']}
# {'57343': ['鏡地獄', 'https://www.aozora.gr.jp/cards/001779/card57343.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_kagami_jigoku.txt']}
# {'58486': ['影男', 'https://www.aozora.gr.jp/cards/001779/card58486.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_kageotoko.txt']}
# {'57506': ['火星の運河', 'https://www.aozora.gr.jp/cards/001779/card57506.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_kaseino_unga.txt']}
# {'56688': ['仮面の恐怖王', 'https://www.aozora.gr.jp/cards/001779/card56688.html', '1959', '/Users/yandongxin/Downloads/edokawa_text_data/1959_kamenno_kyofuo.txt']}
# {'56683': ['奇面城の秘密', 'https://www.aozora.gr.jp/cards/001779/card56683.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_kimenjono_himitsu.txt']}
# {'56658': ['吸血鬼', 'https://www.aozora.gr.jp/cards/001779/card56658.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_kyuketsuki.txt']}
# {'57517': ['恐怖王', 'https://www.aozora.gr.jp/cards/001779/card57517.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_kyofu_o.txt']}
# {'57184': ['疑惑', 'https://www.aozora.gr.jp/cards/001779/card57184.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_giwaku.txt']}
# {'57185': ['黒手組', 'https://www.aozora.gr.jp/cards/001779/card57185.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_kurote_gumi.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1925_fig57185_01.png']}
# {'57405': ['黒蜥蜴', 'https://www.aozora.gr.jp/cards/001779/card57405.html', '1934', '/Users/yandongxin/Downloads/edokawa_text_data/1934_kurotokage.txt']}
# {'57508': ['五階の窓', 'https://www.aozora.gr.jp/cards/001779/card57508.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_gokaino_mado_01.txt']}
# {'57849': ['孤島の鬼', 'https://www.aozora.gr.jp/cards/001779/card57849.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_kotono_oni.txt']}
# {'58039': ['湖畔亭事件', 'https://www.aozora.gr.jp/cards/001779/card58039.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_kohantei_jiken.txt']}
# {'56680': ['サーカスの怪人', 'https://www.aozora.gr.jp/cards/001779/card56680.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_sakasuno_kaijin.txt']}
# {'57518': ['殺人迷路', 'https://www.aozora.gr.jp/cards/001779/card57518.html', '1932', '/Users/yandongxin/Downloads/edokawa_text_data/1932_satsujin_meiro_05.txt']}
# {'57519': ['地獄風景', 'https://www.aozora.gr.jp/cards/001779/card57519.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_jigoku_fukei.txt']}
# {'57316': ['自作解説', 'https://www.aozora.gr.jp/cards/001779/card57316.html', '1965', '/Users/yandongxin/Downloads/edokawa_text_data/1965_jisaku_kaisetsu_kaijin_nijumenso.txt']}
# {'56669': ['少年探偵団', 'https://www.aozora.gr.jp/cards/001779/card56669.html', '1937', '/Users/yandongxin/Downloads/edokawa_text_data/1937_shonen_tanteidan.txt']}
# {'59305': ['女妖', 'https://www.aozora.gr.jp/cards/001779/card59305.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_joyo01.txt']}
# {'57532': ['新宝島', 'https://www.aozora.gr.jp/cards/001779/card57532.html', '1940', '/Users/yandongxin/Downloads/edokawa_text_data/1940_shin_takarajima.txt']}
# {'56646': ['心理試験', 'https://www.aozora.gr.jp/cards/001779/card56646.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_shinri_shiken.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1925_fig56646_01.png']}
# {'54836': ['随筆銭形平次', 'https://www.aozora.gr.jp/cards/001670/card54836.html', '1950', '/Users/yandongxin/Downloads/edokawa_text_data/1950_19tanteishosetsu_konogoro.txt']}
# {'56671': ['青銅の魔人', 'https://www.aozora.gr.jp/cards/001779/card56671.html', '1949', '/Users/yandongxin/Downloads/edokawa_text_data/1949_seidono_majin.txt']}
# {'57186': ['接吻', 'https://www.aozora.gr.jp/cards/001779/card57186.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_seppun.txt']}
# {'57187': ['双生児', 'https://www.aozora.gr.jp/cards/001779/card57187.html', '1924', '/Users/yandongxin/Downloads/edokawa_text_data/1924_soseiji.txt']}
# {'57188': ['算盤が恋を語る話', 'https://www.aozora.gr.jp/cards/001779/card57188.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_sorobanga_koio_kataru_hanashi.txt']}
# {'57106': ['大金塊', 'https://www.aozora.gr.jp/cards/001779/card57106.html', '1939', '/Users/yandongxin/Downloads/edokawa_text_data/1939_dai_kinkai.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1939_fig57106_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1939_fig57106_02.png']}
# {'58462': ['断崖', 'https://www.aozora.gr.jp/cards/001779/card58462.html', '1950', '/Users/yandongxin/Downloads/edokawa_text_data/1950_dangai.txt']}
# {'57502': ['探偵小説の「謎」', 'https://www.aozora.gr.jp/cards/001779/card57502.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_tantei_shosetsuno_nazo.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1954_fig57502_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1954_fig57502_02.png', '/Users/yandongxin/Downloads/edokawa_text_data/1954_fig57502_03.png', '/Users/yandongxin/Downloads/edokawa_text_data/1954_fig57502_04.png', '/Users/yandongxin/Downloads/edokawa_text_data/1954_fig57502_05.png']}
# {'56686': ['探偵少年', 'https://www.aozora.gr.jp/cards/001779/card56686.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_tantei_shonen.txt']}
# {'57533': ['智恵の一太郎', 'https://www.aozora.gr.jp/cards/001779/card57533.html', '1942', '/Users/yandongxin/Downloads/edokawa_text_data/1942_chieno_ichitaro.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1942_fig57533_01.png']}
# {'57107': ['超人ニコラ', 'https://www.aozora.gr.jp/cards/001779/card57107.html', '1962', '/Users/yandongxin/Downloads/edokawa_text_data/1962_chojin_nikora.txt']}
# {'58463': ['月と手袋', 'https://www.aozora.gr.jp/cards/001779/card58463.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_tsukito_tebukuro.txt']}
# {'58464': ['妻に失恋した男', 'https://www.aozora.gr.jp/cards/001779/card58464.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_tsumani_shitsuren_shita_otoko.txt']}
# {'59526': ['妻のこと', 'https://www.aozora.gr.jp/cards/001779/card59526.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_tsumano_koto.txt']}
# {'56650': ['Ｄ坂の殺人事件', 'https://www.aozora.gr.jp/cards/001779/card56650.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_d_zakano_satsujin_jiken.txt']}
# {'57108': ['鉄人Ｑ', 'https://www.aozora.gr.jp/cards/001779/card57108.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_tetsujin_kyu.txt']}
# {'56675': ['鉄塔の怪人', 'https://www.aozora.gr.jp/cards/001779/card56675.html', '1954', '/Users/yandongxin/Downloads/edokawa_text_data/1954_tettono_kaijin.txt']}
# {'56687': ['天空の魔人', 'https://www.aozora.gr.jp/cards/001779/card56687.html', '1956', '/Users/yandongxin/Downloads/edokawa_text_data/1956_tenkuno_majin.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1956_fig56687_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1956_fig56687_02.png', '/Users/yandongxin/Downloads/edokawa_text_data/1956_fig56687_03.png', '/Users/yandongxin/Downloads/edokawa_text_data/1956_fig56687_04.png']}
# {'56689': ['電人Ｍ', 'https://www.aozora.gr.jp/cards/001779/card56689.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_denjin_emu.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1960_fig56689_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1960_fig56689_02.png']}
# {'57109': ['塔上の奇術師', 'https://www.aozora.gr.jp/cards/001779/card57109.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_tojono_kijutsushi.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1958_fig56683_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1958_fig56683_02.png']}
# {'57189': ['盗難', 'https://www.aozora.gr.jp/cards/001779/card57189.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_tonan.txt']}
# {'57229': ['透明怪人', 'https://www.aozora.gr.jp/cards/001779/card57229.html', '1951', '/Users/yandongxin/Downloads/edokawa_text_data/1951_tomei_kaijin.txt']}
# {'57509': ['毒草', 'https://www.aozora.gr.jp/cards/001779/card57509.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_dokuso.txt']}
# {'56672': ['虎の牙', 'https://www.aozora.gr.jp/cards/001779/card56672.html', '1950', '/Users/yandongxin/Downloads/edokawa_text_data/1950_torano_kiba.txt']}
# {'57243': ['何者', 'https://www.aozora.gr.jp/cards/001779/card57243.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_fig57243_001.png', '/Users/yandongxin/Downloads/edokawa_text_data/1929_nanimono.txt']}
# {'56647': ['二銭銅貨', 'https://www.aozora.gr.jp/cards/001779/card56647.html', '1923', '/Users/yandongxin/Downloads/edokawa_text_data/1923_nisen_doka.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1923_fig56647_01.png']}
# {'57190': ['日記帳', 'https://www.aozora.gr.jp/cards/001779/card57190.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_nikkicho.txt']}
# {'57191': ['二癈人', 'https://www.aozora.gr.jp/cards/001779/card57191.html', '1924', '/Users/yandongxin/Downloads/edokawa_text_data/1924_nihaijin.txt']}
# {'56648': ['人間椅子', 'https://www.aozora.gr.jp/cards/001779/card56648.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_ningen_isu.txt']}
# {'58170': ['人間豹', 'https://www.aozora.gr.jp/cards/001779/card58170.html', '1934', '/Users/yandongxin/Downloads/edokawa_text_data/1934_ningen_hyo.txt']}
# {'56676': ['灰色の巨人', 'https://www.aozora.gr.jp/cards/001779/card56676.html', '1955', '/Users/yandongxin/Downloads/edokawa_text_data/1955_haiirono_kyojin.txt']}
# {'57510': ['灰神楽', 'https://www.aozora.gr.jp/cards/001779/card57510.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_haikagura.txt']}
# {'57192': ['白昼夢', 'https://www.aozora.gr.jp/cards/001779/card57192.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_hakuchumu.txt']}
# {'57244': ['白髪鬼', 'https://www.aozora.gr.jp/cards/001779/card57244.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_hakuhatsu_ki.txt']}
# {'56651': ['パノラマ島綺譚', 'https://www.aozora.gr.jp/cards/001779/card56651.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_panoramato_kidan.txt']}
# {'60174': ['薔薇夫人', 'https://www.aozora.gr.jp/cards/001779/card60174.html', '未知', '/Users/yandongxin/Downloads/edokawa_text_data/未知_bara_fujin.txt']}
# {'57511': ['人でなしの恋', 'https://www.aozora.gr.jp/cards/001779/card57511.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_hitodenashino_koi.txt']}
# {'57414': ['一人の芭蕉の問題', 'https://www.aozora.gr.jp/cards/001779/card57414.html', '1947', '/Users/yandongxin/Downloads/edokawa_text_data/1947_hitorino_bashono_mondai.txt']}
# {'57193': ['一人二役', 'https://www.aozora.gr.jp/cards/001779/card57193.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_hitori_futayaku.txt']}
# {'57520': ['火縄銃', 'https://www.aozora.gr.jp/cards/001779/card57520.html', '1932', '/Users/yandongxin/Downloads/edokawa_text_data/1932_hinawaju.txt']}
# {'57194': ['百面相役者', 'https://www.aozora.gr.jp/cards/001779/card57194.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_hyakumenso_yakusha.txt']}
# {'57512': ['覆面の舞踏者', 'https://www.aozora.gr.jp/cards/001779/card57512.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_fukumenno_butosha.txt']}
# {'57230': ['ふしぎな人', 'https://www.aozora.gr.jp/cards/001779/card57230.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_fushigina_hito.txt']}
# {'56659': ['魔術師', 'https://www.aozora.gr.jp/cards/001779/card56659.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_majutsushi.txt']}
# {'56682': ['魔法人形', 'https://www.aozora.gr.jp/cards/001779/card56682.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_maho_ningyo.txt']}
# {'56679': ['魔法博士', 'https://www.aozora.gr.jp/cards/001779/card56679.html', '1956', '/Users/yandongxin/Downloads/edokawa_text_data/1956_maho_hakase.txt']}
# {'57165': ['まほうやしき', 'https://www.aozora.gr.jp/cards/001779/card57165.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_maho_yashiki.txt']}
# {'57245': ['虫', 'https://www.aozora.gr.jp/cards/001779/card57245.html', '1929', '/Users/yandongxin/Downloads/edokawa_text_data/1929_mushi.txt']}
# {'57195': ['夢遊病者の死', 'https://www.aozora.gr.jp/cards/001779/card57195.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_muyubyoshano_shi.txt']}
# {'57521': ['目羅博士の不思議な犯罪', 'https://www.aozora.gr.jp/cards/001779/card57521.html', '1931', '/Users/yandongxin/Downloads/edokawa_text_data/1931_mera_hakaseno_fushigina_hanzai.txt']}
# {'57513': ['木馬は廻る', 'https://www.aozora.gr.jp/cards/001779/card57513.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_mokubawa_mawaru.txt']}
# {'57514': ['モノグラム', 'https://www.aozora.gr.jp/cards/001779/card57514.html', '1926', '/Users/yandongxin/Downloads/edokawa_text_data/1926_monoguramu.txt']}
# {'56684': ['夜光人間', 'https://www.aozora.gr.jp/cards/001779/card56684.html', '1958', '/Users/yandongxin/Downloads/edokawa_text_data/1958_yako_ningen.txt']}
# {'56649': ['屋根裏の散歩者', 'https://www.aozora.gr.jp/cards/001779/card56649.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_yaneurano_sanposha.txt']}
# {'57196': ['幽霊', 'https://www.aozora.gr.jp/cards/001779/card57196.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_yurei.txt']}
# {'58465': ['指', 'https://www.aozora.gr.jp/cards/001779/card58465.html', '1960', '/Users/yandongxin/Downloads/edokawa_text_data/1960_yubi.txt']}
# {'57197': ['指環', 'https://www.aozora.gr.jp/cards/001779/card57197.html', '1925', '/Users/yandongxin/Downloads/edokawa_text_data/1925_yubiwa.txt']}
# {'56670': ['妖怪博士', 'https://www.aozora.gr.jp/cards/001779/card56670.html', '1938', '/Users/yandongxin/Downloads/edokawa_text_data/1938_yokai_hakase.txt']}
# {'56681': ['妖人ゴング', 'https://www.aozora.gr.jp/cards/001779/card56681.html', '1957', '/Users/yandongxin/Downloads/edokawa_text_data/1957_yojin_gongu.txt']}
# {'56691': ['妖星人Ｒ', 'https://www.aozora.gr.jp/cards/001779/card56691.html', '1961', '/Users/yandongxin/Downloads/edokawa_text_data/1961_yoseijin_r.txt', '/Users/yandongxin/Downloads/edokawa_text_data/1961_fig56691_01.png', '/Users/yandongxin/Downloads/edokawa_text_data/1961_fig56691_02.png']}
# {'57522': ['妖虫', 'https://www.aozora.gr.jp/cards/001779/card57522.html', '1933', '/Users/yandongxin/Downloads/edokawa_text_data/1933_yochu.txt']}
# {'58467': ['猟奇の果', 'https://www.aozora.gr.jp/cards/001779/card58467.html', '1930', '/Users/yandongxin/Downloads/edokawa_text_data/1930_ryokino_hate.txt']}

# %%
def save_books_to_csv(book_dict_list, output_file):
    # list を CSV 形式に変換して保存する
    data = []
    
    for book_dict in book_dict_list:
        for book_id, book_info in book_dict.items():
            book_name = book_info[0]
            book_url = book_info[1]
            publication_year = book_info[2] if len(book_info) > 2 else "未知"
            extracted_files = book_info[3:] if len(book_info) > 3 else []
            extracted_files_str = "; ".join(extracted_files)
            
            data.append([book_id, book_name, book_url, publication_year, extracted_files_str])
    
    df = pd.DataFrame(data, columns=["Book ID", "Book Name", "Download Link", "Publication Year", "File Save Path"])
    df["text"] = ""
    df.to_csv(output_file, index=False, encoding="shift_jis")

csv_file_path = "/Users/yandongxin/Downloads/edokawa_text_data/books.csv"

save_books_to_csv(books, csv_file_path)

print(f"CSV fileが保存されている場所: {csv_file_path}")
# Out:
# CSV fileが保存されている場所: /Users/yandongxin/Downloads/edokawa_text_data/books.csv

# %%
def process_text(file_path):
    # 指定されたtext fileを処理し、不要な情報を削除する
    if pd.isna(file_path) or not os.path.exists(file_path):
        return None  # file が存在しない場合は None を返す

    # Shift_JIS でファイルを読み込む
    try:
        with open(file_path, "r", encoding="shift_jis", errors="ignore") as f:
            text = f.readlines()
    except Exception as e:
        print(f"ファイル読み込みエラー: {file_path} - {e}")
        return None

    # list形式のtextを文字列に変換
    text = [line.strip() for line in text]

    # 《》内の内容を削除
    text = [re.sub(r"《[^》]*》", "", line) for line in text]

    # ［＃］ 内の内容（前の数字も含む）を削除
    text = [re.sub(r"\d*［＃[^］]*］", "", line) for line in text]

    # ヘッダーの不要部分を削除（最後の `-------------------------------------------------------` の後の部分を残す）
    if "-------------------------------------------------------" in text:
        start_idx = len(text) - 1 - text[::-1].index("-------------------------------------------------------")
        text = text[start_idx + 1 :]

    # フッターの「底本：」以降を削除
    end_idx = next((i for i, line in enumerate(text) if line.startswith("底本：")), None)
    if end_idx is not None:
        text = text[:end_idx]

    # 空行を削除
    text = [line for line in text if line]

    # 処理後のテキストを改行で結合
    return "\n".join(text)


# CSV ファイルの読み込み（Shift_JIS）
csv_file = "/Users/yandongxin/Downloads/edokawa_text_data/books.csv"
df = pd.read_csv(csv_file, encoding="shift_jis")

# CSV に "file save path" 列があるか確認
if "File Save Path" not in df.columns:
    raise ValueError("CSV ファイルに 'File Save Path' 列がありません")

# 各ファイルを処理し、結果を "text" 列に格納
df["text"] = df["File Save Path"].apply(process_text)

# 処理後のデータを CSV に Shift_JIS で保存（行番号なし）
df.to_csv(csv_file, index=False, encoding="shift_jis")

print("テキスト処理が完了し、結果を Shift_JIS で CSV に保存しました。")
# Out:
# テキスト処理が完了し、結果を Shift_JIS で CSV に保存しました。

# %%
def check_text_column(csv_file):
    df = pd.read_csv(csv_file, encoding="shift_jis") 
    if "text" not in df.columns:
        print("csv fileの中に「text」列がない。")
        return

    empty_rows = df["text"].isna() | df["text"].str.strip().eq("")

    if empty_rows.any():
        print("「text」列は空であるか、スペースのみが含まれている行:")
        print(df[empty_rows])
    else:
        print("すべての行の「text」列の中に内容がある。")

csv_file = "/Users/yandongxin/Downloads/edokawa_text_data/books.csv"
check_text_column(csv_file)
# Out:
# 「text」列は空であるか、スペースのみが含まれている行:
#      Book ID Book Name                                      Download Link  \
# 3      57515        悪霊  https://www.aozora.gr.jp/cards/001779/card5751...
# 13     57241      黄金仮面  https://www.aozora.gr.jp/cards/001779/card5724...
# 20     56690  おれは二十面相だ  https://www.aozora.gr.jp/cards/001779/card5669...
# 21     56673    怪奇四十面相  https://www.aozora.gr.jp/cards/001779/card5667...
# 35     57185       黒手組  https://www.aozora.gr.jp/cards/001779/card5718...
# 47     56646      心理試験  https://www.aozora.gr.jp/cards/001779/card5664...
# 53     57106       大金塊  https://www.aozora.gr.jp/cards/001779/card5710...
# 55     57502  探偵小説の「謎」  https://www.aozora.gr.jp/cards/001779/card5750...
# 57     57533    智恵の一太郎  https://www.aozora.gr.jp/cards/001779/card5753...
# 65     56687     天空の魔人  https://www.aozora.gr.jp/cards/001779/card5668...
# 66     56689       電人Ｍ  https://www.aozora.gr.jp/cards/001779/card5668...
# 67     57109    塔上の奇術師  https://www.aozora.gr.jp/cards/001779/card5710...
# 72     57243        何者  https://www.aozora.gr.jp/cards/001779/card5724...
# 73     56647      二銭銅貨  https://www.aozora.gr.jp/cards/001779/card5664...
# 107    56691      妖星人Ｒ  https://www.aozora.gr.jp/cards/001779/card5669...
#
#     Publication Year                                     File Save Path text
# 3               1933  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 13              1930  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 20              1960  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 21              1952  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 35              1925  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 47              1925  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 53              1939  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 55              1954  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 57              1942  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 65              1956  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 66              1960  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 67              1958  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 72              1929  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 73              1923  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
# 107             1961  /Users/yandongxin/Downloads/edokawa_text_data/...  NaN
